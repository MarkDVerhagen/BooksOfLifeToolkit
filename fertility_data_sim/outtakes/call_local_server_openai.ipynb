# %%
2+2
# Out:
# 4

# %%
from openai import OpenAI
client = OpenAI(
    base_url = "http://localhost:8080/v1",
    api_key = "required_but_not_used"
)

# %%
completion = client.chat.completions.create(
  model="required_but_not_used",
  messages=[
    {"role": "system", "content": "You are a poetic assistant, skilled in explaining complex programming concepts with creative flair."},
    {"role": "user", "content": "Compose a poem that explains the concept of recursion in programming."}
  ], 
  max_tokens=20,
  temperature=0.8,
)

print(completion)
# Out:
# ChatCompletion(id='chatcmpl-jGJcNiUEj9FYAEzg4TfkeGhJIJ674Qzj', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content=' In the realm of code, where logic prevails,\nA concept weaves, a tale', role='assistant', function_call=None, tool_calls=None))], created=1719763363, model='required_but_not_used', object='chat.completion', system_fingerprint=None, usage=CompletionUsage(completion_tokens=20, prompt_tokens=39, total_tokens=59))
